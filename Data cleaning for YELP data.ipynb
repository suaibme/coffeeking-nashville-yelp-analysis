# %%
# %sql
-- DATA CLEANING
-- First, I'll delete the attributes column (as I may not use it), and the rescued data colum for all being null

-- Enable column mapping to allow dropping columns
ALTER TABLE yelp_academic_dataset_nash_business_22
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

-- Now, I'll drop these two columns
ALTER TABLE yelp_academic_dataset_nash_business_22
DROP COLUMN attributes;
DROP COLUMN _rescued_data;

-- creating new columns to be used to separate the hours column
ALTER TABLE yelp_academic_dataset_nash_business_22 ADD COLUMN monday_hours string;
ALTER TABLE yelp_academic_dataset_nash_business_22 ADD COLUMN tuesday_hours string;
ALTER TABLE yelp_academic_dataset_nash_business_22 ADD COLUMN wednesday_hours string;
ALTER TABLE yelp_academic_dataset_nash_business_22 ADD COLUMN thursday_hours string;
ALTER TABLE yelp_academic_dataset_nash_business_22 ADD COLUMN friday_hours string;
ALTER TABLE yelp_academic_dataset_nash_business_22 ADD COLUMN saturday_hours string;
ALTER TABLE yelp_academic_dataset_nash_business_22 ADD COLUMN sunday_hours string;

-- Now, I'll split the hours column into the new columns
UPDATE yelp_academic_dataset_nash_business_22 SET monday_hours = get_json_object(hours, '$.Monday');
UPDATE yelp_academic_dataset_nash_business_22 SET tuesday_hours = get_json_object(hours, '$.Tuesday');
UPDATE yelp_academic_dataset_nash_business_22 SET wednesday_hours = get_json_object(hours, '$.Wednesday');
UPDATE yelp_academic_dataset_nash_business_22 SET thursday_hours = get_json_object(hours, '$.Thursday');
UPDATE yelp_academic_dataset_nash_business_22 SET friday_hours = get_json_object(hours, '$.Friday');
UPDATE yelp_academic_dataset_nash_business_22 SET saturday_hours = get_json_object(hours, '$.Saturday');
UPDATE yelp_academic_dataset_nash_business_22 SET sunday_hours = get_json_object(hours, '$.Sunday')

-- Working on the Checkin table - separating the date column, which is a string of different time and date slots
CREATE OR REPLACE TABLE yelp_academic_dataset_nash_checkin AS 
SELECT 
  business_id,
  explode(split(checkin, ',')) AS checin_date
FROM yelp_academic_dataset_nash_checkin;

-- Now, I'll split the date column into the new columns
ALTER TABLE yelp_academic_dataset_nash_checkin ADD COLUMN date string;
ALTER TABLE yelp_ac
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-2977093483160144>, line 1
# ...
